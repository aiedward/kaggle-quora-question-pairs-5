# %%
import pandas as pd

# %%
train_lda = pd.read_csv("data/train_lda_feat.csv", encoding="ISO-8859-1")
train_lda.iloc[:,6:].head()
# Out:
#    cosine_distance_lda  cityblock_distance_lda  jaccard_distance_lda  \
# 0             0.046653                0.232798                   1.0
# 1             0.748658                1.241746                   1.0
# 2             0.591752                1.089333                   1.0
# 3             1.000000                1.642870                   1.0
# 4             0.635290                1.337222                   1.0
#
#    canberra_distance_lda  euclidean_distance_lda  minkowski_distance_lda  \
# 0               1.266667                0.137590                0.127564
# 1               5.400000                0.538923                0.423051
# 2               6.333333                0.411444                0.304798
# 3               7.000000                0.678982                0.530331
# 4               9.757361                0.428130                0.304331
#
#    braycurtis_distance_lda
# 0                 0.134090
# 1                 0.812442
# ...

# %%
test_lda = pd.read_csv("data/test_lda_feat.csv", encoding="ISO-8859-1")

# %%
.head()
# Out:
#    cosine_distance_lda  cityblock_distance_lda  jaccard_distance_lda  \
# 0         5.733411e-01            1.160190e+00                   1.0
# 1         2.510204e-01            6.154087e-01                   1.0
# 2         3.844232e-01            7.492682e-01                   1.0
# 3         1.000000e+00            1.170556e+00                   1.0
# 4        -2.220446e-16            5.551115e-17                   0.5
#
#    canberra_distance_lda  euclidean_distance_lda  minkowski_distance_lda  \
# 0           7.833784e+00            3.996628e-01            2.906315e-01
# 1           3.595264e+00            2.650330e-01            2.101561e-01
# 2           2.813749e+00            3.688321e-01            3.097811e-01
# 3           3.000000e+00            6.894749e-01            5.858460e-01
# 4           8.299009e-17            5.551115e-17            5.551115e-17
#
#    braycurtis_distance_lda
# 0             6.583797e-01
# 1             3.591297e-01
# ...
